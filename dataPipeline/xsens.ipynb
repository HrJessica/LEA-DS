# %%
import os
import json
import pickle
import shutil
import pandas as pd
import numpy as np
data_path = 'Xsens_dosHz.p'
with open(data_path, 'rb') as f:
    xsens_data = pickle.load(f)
print(xsens_data)
# Out:
# {'Sujet1_T1':             Fn         In         Rn        Fed        Aed        Feg  \
# 0    37.348219   7.011783   1.761391  27.472905  -9.789125  25.802076
# 1    37.411160   6.782392   1.617980  27.675553 -10.021214  25.914734
# 2    36.588496   6.477838   1.485147  27.973562  -9.780203  26.025437
# 3    31.987994   5.999297   1.960542  31.092095  -9.334077  28.047733
# 4    24.443419   4.863046   3.708621  39.627553 -11.349337  35.083211
# ..         ...        ...        ...        ...        ...        ...
# 475  31.359045  11.891189   9.977304  12.750898   2.033512  -0.297464
# 476  30.999740   6.016885   7.600110  17.314524   3.573952   2.944849
# 477  29.124595   3.220332   3.434209  19.075055   5.017693   4.978647
# 478  25.072331   2.291341   5.000686  19.151671   7.885447   5.253320
# 479  20.244058   2.360502  13.706121  16.788178   8.585420   5.347350
#
#            Aeg         Ft         It        Rt        Fcd        Fcg  \
# ...
