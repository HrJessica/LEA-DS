# %%
import os
import json
import pickle
import shutil
import pandas as pd
import numpy as np
data_path = 'Xsens_profil.p'
with open(data_path, 'rb') as f:
    xsens_data = pickle.load(f)
print(xsens_data)
# Out:
# {'Sujet1_T1':              Fn         In        Rn        Fed        Aed        Feg  \
# 0     37.348219   7.011783  1.761391  27.472905  -9.789125  25.802076
# 1     37.388306   6.960484  1.738679  27.563775  -9.855359  25.875504
# 2     37.492798   6.907335  1.692679  27.616522  -9.900642  25.907456
# 3     37.557703   6.861944  1.654584  27.651984  -9.938517  25.924650
# 4     37.528633   6.829148  1.638519  27.669747  -9.976051  25.929912
# ...         ...        ...       ...        ...        ...        ...
# 2760  31.019286  10.399701  1.546299  77.006278 -20.994237  68.093635
# 2761  33.596361  11.443496  0.673600  79.055905 -22.963531  70.991794
# 2762  35.561565  10.612905  0.069503  77.112198 -21.410109  68.901443
# 2763  37.976530   9.708958  0.778714  75.189960 -19.764039  66.775150
# 2764  38.724046   9.621516  0.956818  75.056320 -19.615390  66.649226
#
#             Aeg         Ft        It        Rt        Fcd        Fcg  \
# ...
